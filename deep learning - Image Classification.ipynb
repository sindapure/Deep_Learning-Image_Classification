# %%
# !pip install tensorflow

# %%
import tensorflow as tf ## pip install tensorflow

# %%
import numpy as np ## pip install numpy

# %%
from IPython.display import Image ## first method to read image

Image(filename='dolphin.jpg', width=224, height=224)

# %%
from tensorflow.keras.preprocessing import image ##second method to read image
img = image.load_img('dolphin.jpg', target_size = (224,224))

# %%
import matplotlib.pyplot as plt     ##conda install -c conda-forge matplotlib

# %%
plt.imshow(img)

# %%
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 14.1 MB/s eta 0:00:0000:0100:01
# ...

# %%
import cv2   ##instal opencv-python.  ##third method to load an image

# %%
imgg = cv2.imread('dolphin.jpg')

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %%
from PIL import Image ## pip install Pillow   ##fourth method to load an image

# %%
im = Image.open('dolphin.jpg')  ##PIL

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# ## lets load the deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet() ## deep learning models weights - pre-trained

# %%
## creating  amodel
## training a model
## test or variable 
## Predict

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()
# Out:
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# Pre-processing of the Image

# %%
filename = 'parrot.webp'

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('parrot.webp', target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis = 0) ## need fourth dimension
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %% [raw]
# predictions = mobile.predict(final_image)

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n01818515', 'macaw', 0.88362086), ('n01820546', 'lorikeet', 0.0056151953), ('n01514668', 'cock', 0.0042417804), ('n01828970', 'bee_eater', 0.0012845668), ('n01819313', 'sulphur-crested_cockatoo', 0.0012091466)]]
